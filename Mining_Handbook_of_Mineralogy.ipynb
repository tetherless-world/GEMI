# %%
#########################################
### Mining the Handbook of Mineralogy ###
#########################################

# %%
import os
import xml.etree.ElementTree
import re

# %%
minerals = {}

# %%
# index = "./pdfs/handbook_index.xml"
index = "./hom_index.xml"

# filename = "../../RDA/PyNLP/CID-LCSS-sample.xml"
# xmlDoc = xml.etree.ElementTree.parse(filename).getroot()
# for element in xmlDoc.iter('a'):
#     print element.text

files = []

with open(index,'r') as f:
    text = f.read().split('href="')
    
    with open("handbook_urls1",'w') as f1:
        for item in text:
            if ('pdf' in item):
    #             filename = "http://rruff.info/doclib/hom/"+item[0:item.find('"')].strip()
                filename = "http://www.handbookofmineralogy.org/"+item[0:item.find('"')].strip()
                files.append(filename)
    #             print filename
                f1.write(filename+"\n")

# %%
def findnth(haystack, needle, n):
    parts= haystack.split(needle, n+1)
    if len(parts)<=n+1:
        return -1
    return len(haystack)-len(parts[-1])-len(needle)

# %%
with open("handbook_urls",'w') as f:
    f.write(str(files))

# %%
for (path,names,filenames) in os.walk('./raw text1/'):
    for filename in filenames:
        print filename
# Out:
# .DS_Store
# abelsonite.txt
# abernathyite.txt
# abhurite.txt
# abramovite.txt
# abswurmbachite.txt
# acanthite.txt
# acetamide.txt
# actinolite.txt
# acuminite.txt
# adachiite.txt
# adamite.txt
# adamsite-(Y).txt
# adelite.txt
# admontite.txt
# adolfpateraite.txt
# adranosite-(Fe).txt
# adranosite.txt
# aegirine.txt
# aenigmatite.txt
# aerinite.txt
# aerugite.txt
# aeschynite-(Ce).txt
# aeschynite-(Nd).txt
# aeschynite-(Y).txt
# afghanite.txt
# afmite.txt
# afwillite.txt
# agardite-(LA).txt
# agardite-(Y).txt
# agrellite.txt
# agrinierite.txt
# aguilarite.txt
# aheylite.txt
# ahlfeldite.txt
# aikinite.txt
# ajoite.txt
# akaganeite.txt
# akatoreite.txt
# akdalaite.txt
# akermanite.txt
# akhtenskite.txt
# aklimaite.txt
# akrochordite.txt
# aksaite.txt
# aktashite.txt
# alabandite.txt
# alacranite.txt
# alamosite.txt
# alarsite.txt
# albite.txt
# albrechtschraufite.txt
# alcaparrosaite.txt
# aldermanite.txt
# aleksandrovite.txt
# aleksite.txt
# alflarsenite.txt
# alforsite.txt
# ...

# %%
minerals = {}
with open("mineral_attrs.csv",'w') as fw:
    fw.write('filename'+'\t'+'mineral name'+'\t'+'a'+'\t'+'b'+'\t'+'c'+'\t'+'alpha'+'\t'+'beta'+'\t'+'gamma'+'\t'+'Z'+'\t'+'hardness'+'\t'+'color'+'\t'+'luster'+'\n')
    for filename in filenames:
        if filename != '.DS_Store':
            with open("./raw text/"+filename,'r') as f:

            #         text = f.read().split('\n\n')
                    text = f.read()

                    filename = filename.split('.')[0].strip()
#                     mineral = text.split('\n\n')[0].split('  ')[0].strip()
                    mineral = text.split('\n')[0].split('  ')[0].strip()

        #             print "\n"+mineral+":"

                    attr_list = []
                    a=''
                    b=''
                    c=''
                    alpha=''
                    beta=''
                    gamma=''
                    Z=''
                    hardness=''
                    color=''
                    luster=''

                    # Cell Data
                    section = text.find('Cell Data')
                    start = text.find('Z =',section)
                    if (start != -1):
                        start = start + 4
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)

                        Z = text[start:min(end1,end2)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else:
                        start = text.find('Z=',section)
                        if (start != -1):
                            start = start + 3
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)

                            Z = text[start:min(end1,end2)].strip().replace('\t',' ').replace('\n',' ')



                    start = text.find('a =',section)
                    if (start != -1):
                        start = start + 4
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)
                        end3 = text.find(')',start) + 1

                        a = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else: 
                        start = text.find('a=')
                        if (start != -1):
                            start = start + 3
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)
                            end3 = text.find(')',start) + 1

                            a = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')

                    start = text.find('b =',section)
                    if (start != -1):
                        start = start + 4
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)
                        end3 = text.find(')',start) + 1

                        b = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else: 
                        start = text.find('b=')
                        if (start != -1):
                            start = start + 3
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)
                            end3 = text.find(')',start) + 1

                            b = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')



                    start = text.find('c =',section)
                    if (start != -1):
                        start = start + 4
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)
                        end3 = text.find(')',start) + 1

                        c = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else: 
                        start = text.find('c=')
                        if (start != -1):
                            start = start + 3
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)
                            end3 = text.find(')',start) + 1

                            c = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')



                    start = text.find('α =',section)
                    if (start != -1):
                        start = start + 5
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)
                        end3 = text.find(')',start) + 1

                        alpha = text[start-1:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else: 
                        start = text.find('α=')
                        if (start != -1):
                            start = start + 4
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)
                            end3 = text.find(')',start) + 1

                            alpha = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')


                    start = text.find('β =',section)
                    if (start != -1):
                        start = start + 5
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)
                        end3 = text.find(')',start) + 1

                        beta = text[start-1:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else: 
                        start = text.find('β=')
                        if (start != -1):
                            start = start + 4
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)
                            end3 = text.find(')',start) + 1

                            beta = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')


                    start = text.find('γ =',section)
                    if (start != -1):
                        start = start + 5
                        end1 = text.find(' ',start)
                        end2 = text.find('\n',start)
                        end3 = text.find(')',start) + 1

                        gamma = text[start-1:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
                    else: 
                        start = text.find('γ=')
                        if (start != -1):
                            start = start + 4
                            end1 = text.find(' ',start)
                            end2 = text.find('\n',start)
                            end3 = text.find(')',start) + 1

                            gamma = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')

        #             # crystal system
        #             start = text.find('Crystal Data:')
        #             if (start != -1):
        #                 start += 15
        #                 end1 = text.find('.',start)
        #                 end2 = text.find(',',start)
        #                 end3 = text.find(';',start)
        #                 end4 = text.find(' ',start)

        #                 crystal_system = text[start-1:min(end1,end2,end3,end4)]

        
        
                    # hardness
                    start = text.find('Hardness')
                    if (start != -1):
                        start += 11
                        end1 = text.find('.',start)
                        end2 = text.find(', ',start)
                        end3 = text.find(';',start)
                        end4 = text.find(' ',start)
                        end5 = text.find('\n',start)

                        hardness = text[start-1:min(end1,end2,end3,end4,end5)].strip().replace('\t',' ').replace('\n',' ').replace('",','~').strip()

                        if (hardness == '<' or hardness == '>'):
                            end1 = text.find('.',start+2)
                            end2 = text.find(',',start+2)
                            end3 = text.find(';',start+2)
                            end4 = text.find(' ',start+2)
                            end5 = text.find('\n',start+2)
                            hardness = text[start-1:min(end1,end2,end3,end4,end5)].strip().replace('\t',' ').replace('\n',' ')

                    # color
                    start = text.find('Color')
                    if (start != -1):
                        start += 7
                        end1 = text.find('.',start)

                        color = text[start-1:end1].strip().replace('\t',' ').replace('\n',' ')

                    # luster
                    start = text.find('Luster')
                    if (start != -1):
                        start += 8
                        end1 = text.find('.',start)

                        luster = text[start-1:end1].strip().replace('\t',' ').replace('\n',' ')
                        
#                         if mineral=="abramovite":
#                             print 'a:',a,'b:',b,'c:',c,'alpha:',alpha,'beta:',beta,'gamma:',gamma,'Z:',Z,'hardness:',hardness,'color:',color,'luster:',luster
#                     print mineral,a,b,c,alpha,beta,gamma,Z,hardness,color,luster

                    attr_list.append(a)
                    attr_list.append(b)
                    attr_list.append(c)
                    attr_list.append(alpha)
                    attr_list.append(beta)
                    attr_list.append(gamma)
                    attr_list.append(Z)
                    attr_list.append(hardness)
                    attr_list.append(color)
                    attr_list.append(luster)

                    minerals[mineral] = attr_list

fw.write(filename+'\t'+mineral+'\t'+a+'\t'+b+'\t'+c+'\t'+alpha+'\t'+beta+'\t'+gamma+'\t'+Z+'\t'+hardness+'\t'+color+'\t'+luster+'\n')
#                     fw.write(mineral+'\n')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-7c1605be5def> in <module>()
#       4     for filename in filenames:
#       5         if filename != '.DS_Store':
# ----> 6             with open("./raw text/"+filename,'r') as f:
#       7
#       8             #         text = f.read().split('\n\n')
#
# IOError: [Errno 2] No such file or directory: './raw text/adachiite.txt'

# %%
# minerals = {}
# with open("mineral_attrs.csv",'w') as fw:
#     fw.write('filename'+'\t'+'mineral name'+'\t'+'a'+'\t'+'b'+'\t'+'c'+'\t'+'alpha'+'\t'+'beta'+'\t'+'gamma'+'\t'+'Z'+'\t'+'hardness'+'\t'+'density (measured)'+'\t'+'density (calculated)'+'\t'+'color'+'\t'+'luster'+'\n')
#     for filename in filenames:
#         if filename != '.DS_Store':
#             with open("./raw text1/"+filename,'r') as f:

#             #         text = f.read().split('\n\n')
#                     text = f.read().replace('"',' ')

#                     filename = filename.split('.')[0].strip()
# #                     mineral = text.split('\n\n')[0].split('  ')[0].strip()
#                     mineral = text.split('\n')[0].split('  ')[0].strip()

#         #             print "\n"+mineral+":"

#                     attr_list = []
#                     a=''
#                     b=''
#                     c=''
#                     alpha=''
#                     beta=''
#                     gamma=''
#                     Z=''
#                     hardness=''
#                     color=''
#                     luster=''

#                     # Cell Data
#                     section = text.find('Cell Data')
#                     start = text.find('Z =',section)
#                     if (start != -1):
#                         start = start + 4
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)

#                         Z = text[start:min(end1,end2)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else:
#                         start = text.find('Z=',section)
#                         if (start != -1):
#                             start = start + 3
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)

#                             Z = text[start:min(end1,end2)].strip().replace('\t',' ').replace('\n',' ')



#                     start = text.find('a =',section)
#                     if (start != -1):
#                         start = start + 4
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)
#                         end3 = text.find(')',start) + 1

#                         a = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else: 
#                         start = text.find('a=')
#                         if (start != -1):
#                             start = start + 3
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)
#                             end3 = text.find(')',start) + 1

#                             a = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')

#                     start = text.find('b =',section)
#                     if (start != -1):
#                         start = start + 4
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)
#                         end3 = text.find(')',start) + 1

#                         b = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else: 
#                         start = text.find('b=')
#                         if (start != -1):
#                             start = start + 3
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)
#                             end3 = text.find(')',start) + 1

#                             b = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')



#                     start = text.find('c =',section)
#                     if (start != -1):
#                         start = start + 4
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)
#                         end3 = text.find(')',start) + 1

#                         c = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else: 
#                         start = text.find('c=')
#                         if (start != -1):
#                             start = start + 3
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)
#                             end3 = text.find(')',start) + 1

#                             c = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')



#                     start = text.find('α =',section)
#                     if (start != -1):
#                         start = start + 5
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)
#                         end3 = text.find(')',start) + 1

#                         alpha = text[start-1:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else: 
#                         start = text.find('α=')
#                         if (start != -1):
#                             start = start + 4
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)
#                             end3 = text.find(')',start) + 1

#                             alpha = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')


#                     start = text.find('β =',section)
#                     if (start != -1):
#                         start = start + 5
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)
#                         end3 = text.find(')',start) + 1

#                         beta = text[start-1:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else: 
#                         start = text.find('β=')
#                         if (start != -1):
#                             start = start + 4
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)
#                             end3 = text.find(')',start) + 1

#                             beta = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')


#                     start = text.find('γ =',section)
#                     if (start != -1):
#                         start = start + 5
#                         end1 = text.find(' ',start)
#                         end2 = text.find('\n',start)
#                         end3 = text.find(')',start) + 1

#                         gamma = text[start-1:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')
                        
#                     else: 
#                         start = text.find('γ=')
#                         if (start != -1):
#                             start = start + 4
#                             end1 = text.find(' ',start)
#                             end2 = text.find('\n',start)
#                             end3 = text.find(')',start) + 1

#                             gamma = text[start:min(end1,end2,end3)].strip().replace('\t',' ').replace('\n',' ')

#         #             # crystal system
#         #             start = text.find('Crystal Data:')
#         #             if (start != -1):
#         #                 start += 15
#         #                 end1 = text.find('.',start)
#         #                 end2 = text.find(',',start)
#         #                 end3 = text.find(';',start)
#         #                 end4 = text.find(' ',start)

#         #                 crystal_system = text[start-1:min(end1,end2,end3,end4)]

        

#                     ## Physical Properties
#                     ph_start = text.find('Physical Properties:')
#                     ph_end = text.find('Properties',ph_start+20)
                    
#                     if (ph_start != -1 and ph_end != -1):
#                         ph_props = [prop for prop in text[ph_start:ph_end].replace('\n',' ').split(' ')]
            
# #                     print ph_props

#                     # hardness
#                     try:
#                         hardness_st = ph_props.index('Hardness')
#                     except ValueError:
#                         hardness_st = -1
                    
#                     if (hardness_st != -1):
#                         if (ph_props[hardness_st+1]=="="):
#                             hardness_st += 2
#                             hardness = ph_props[hardness_st]
#                         else:
#                             hardness_st += 1
#                             hardness = ph_props[hardness_st]

#                         if (hardness == "<" or hardness == ">"):
#                             hardness += ph_props[hardness_st+1]

#                     # Density
#                     try:
#                         dm_st = ph_props.index('D(meas.)')
#                     except ValueError:
#                         dm_st = -1
                    
#                     if (dm_st != -1):
#                         if (ph_props[dm_st+1]=="="):
#                             dm_st += 2
#                             density_meas = ph_props[dm_st]
#                         else:
#                             dm_st += 1
#                             density_meas = ph_props[dm_st]

#                         if (density_meas == "<" or density_meas == ">"):
#                             density_meas += ph_props[dm_st+1]

#                     try:
#                         dc_st = ph_props.index('D(calc.)')
#                     except ValueError:
#                         dc_st = -1
                    
#                     if (dc_st != -1):
#                         if (ph_props[dc_st+1]=="="):
#                             dc_st += 2
#                             density_calc = ph_props[dc_st]
#                         else:
#                             dc_st += 1
#                             density_calc = ph_props[dc_st]

#                         if (density_calc == "<" or density_calc == ">"):
#                             density_calc += ph_props[dc_st+1]


#                     # color
#                     start = text.find('Color')
#                     if (start != -1):
#                         start += 7
#                         end1 = text.find('.',start)

#                         color = text[start-1:end1].strip().replace('\t',' ').replace('\n',' ')

#                     # luster
#                     start = text.find('Luster')
#                     if (start != -1):
#                         start += 8
#                         end1 = text.find('.',start)

#                         luster = text[start-1:end1].strip().replace('\t',' ').replace('\n',' ')
                        
# #                         if mineral=="abramovite":
# #                             print 'a:',a,'b:',b,'c:',c,'alpha:',alpha,'beta:',beta,'gamma:',gamma,'Z:',Z,'hardness:',hardness,'color:',color,'luster:',luster
# #                     print mineral,a,b,c,alpha,beta,gamma,Z,hardness,density_meas,density_calc,color,luster

#                     ## postprocessing
    
#                     # hardness

#                     hardness = hardness.replace('∼','').replace('[','').replace(']','').replace('»','>').replace('{','-')

#                     attr_list.append(a)
#                     attr_list.append(b)
#                     attr_list.append(c)
#                     attr_list.append(alpha)
#                     attr_list.append(beta)
#                     attr_list.append(gamma)
#                     attr_list.append(Z)
#                     attr_list.append(hardness)
#                     attr_list.append(color)
#                     attr_list.append(luster)

#                     minerals[mineral] = attr_list

#                     fw.write(filename+'\t'+mineral+'\t'+a+'\t'+b+'\t'+c+'\t'+alpha+'\t'+beta+'\t'+gamma+'\t'+Z+'\t'+hardness+'\t'+density_meas+'\t'+density_calc+'\t'+color+'\t'+luster+'\n')
# #                     fw.write(mineral+'\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7d63fbe630bc> in <module>()
#       2 with open("mineral_attrs.csv",'w') as fw:
#       3     fw.write('filename'+'\t'+'mineral name'+'\t'+'a'+'\t'+'b'+'\t'+'c'+'\t'+'alpha'+'\t'+'beta'+'\t'+'gamma'+'\t'+'Z'+'\t'+'hardness'+'\t'+'density (measured)'+'\t'+'density (calculated)'+'\t'+'color'+'\t'+'luster'+'\n')
# ----> 4     for filename in filenames:
#       5         if filename != '.DS_Store':
#       6             with open("./raw text1/"+filename,'r') as f:
#
# NameError: name 'filenames' is not defined

# %%
with open("new_minerals.csv",'w') as fw:
    
#     fw.write('IMA'+';'+'Mineral'+';'+'Formula'+';'+'Locality/Authorship'+';'+'Email'+';'+'Relations'+';'+'Crystal Data'+';'+'Unit Cell Params'+';'+'X-ray Powder Pattern'+';'+'Repository'+';'+'Citation'+'\n')
    fw.write('IMA'+','+'Mineral'+','+'Formula'+','+'Locality/Authorship'+','+'Email'+','+'Relations'+','+'Crystal Data'+','+'Unit Cell Params'+','+'X-ray Powder Pattern'+','+'Repository'+','+'Citation'+'\n')
    
    with open("../IMA/MM80_1315.txt",'r') as f:
        text = f.read()

        section_start = text.find("IMA No.")

        while section_start!=-1:

            mineral_sn = text[section_start:text.find('\n',section_start)].strip()

            section_end = text.find('\n\n',section_start+len(mineral_sn)+1)

            section = text[section_start:section_end].replace(',',' ')

            index = 0+len(mineral_sn)+1

            mineral_name = section[index:section.find('\n',index+1)].strip()

            index += len(mineral_name)+1

            chemical_formula = section[index:section.find('\n',index+2)].strip()

            index += len(chemical_formula)+1

            locality_authorship = section[index:section.find('*E-mail',index+2)].strip()

            index += len(locality_authorship)+1

            email = section[index:section.find('\n',index+2)].strip()

            index += len(email)+1

            email = email[email.find(' '):len(email)].strip()

            relations = section[index:section.find('\n',index+2)].strip()

            index += len(relations)+1

            cryst_data = section[index:section.find('\n',index+2)].strip()

            index += len(cryst_data)+1

            cell_params = section[index:section.find('\n',index+2)].strip()

            index += len(cell_params)+1

            next_line = section[index:section.find('\n',index+2)]
        
            if not is_number(next_line.strip()[0]):
                cell_params += ' '+next_line.strip()
                index += len(next_line)+1

            diff_lines = section[index:section.find('\n',index+2)].strip()

            index += len(diff_lines)+1

            next_line = section[index:section.find('\n',index+2)].strip()

            if is_number(next_line.strip()[0]):
                diff_lines += ' '+next_line
                index += len(next_line)+1

            repo = section[index:section.find('How to cite:',index+2)].strip()

            index += len(repo)+1

            citation = section[section.find('How to cite: ')+12:len(section)].strip()
            
            locality_authorship = locality_authorship.replace('\n',' ')
            cryst_data = cryst_data.replace('\n',' ')
            cell_params = cell_params.replace('\n',' ')
            diff_lines = diff_lines.replace('\n',' ')
            repo = repo.replace('\n',' ')
            citation = citation.replace('\n',' ')

#             print mineral_sn,'\n',mineral_name,'\n',chemical_formula,'\n',locality_authorship,'\n',email,'\n',relations,'\n',phys_props,'\n',cell_params,'\n',diff_lines,'\n',repo,'\n',citation,'\n'

#             fw.write(mineral_sn+'\t'+mineral_name+'\t'+chemical_formula+'\t'+locality_authorship+'\t'+email+'\t'+relations+'\t'+cryst_data+'\t'+cell_params+'\t'+diff_lines+'\t'+repo+'\t'+citation+'\n')
            fw.write(mineral_sn+','+mineral_name+','+chemical_formula+','+locality_authorship+','+email+','+relations+','+cryst_data+','+cell_params+','+diff_lines+','+repo+','+citation+'\n')
#             fw.write(mineral_sn+';'+mineral_name+';'+chemical_formula+';'+locality_authorship+';'+email+';'+relations+';'+cryst_data+';'+cell_params+';'+diff_lines+';'+repo+';'+citation+'\n')

            section_start = text.find("IMA No.",section_end)

# %%
def is_number(s):
    try:
        int(s)
        return True
    except ValueError:
        return False
